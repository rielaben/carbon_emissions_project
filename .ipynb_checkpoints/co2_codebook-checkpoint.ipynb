# %% [markdown]
# This codebook acts like our data dictionary, we can reference this when we need to find out what certain columns mean

# %%
import pandas as pd
codebook = pd.read_csv("co2-data/owid-co2-codebook.csv")
codebook
# Out:
#                                  column  \
# 0                              iso_code
# 1                               country
# 2                                  year
# 3                                   co2
# 4                       co2_growth_prct
# 5                        co2_growth_abs
# 6                       consumption_co2
# 7                             trade_co2
# 8                       trade_co2_share
# 9                        co2_per_capita
# 10           consumption_co2_per_capita
# 11                     share_global_co2
# 12                       cumulative_co2
# 13          share_global_cumulative_co2
# 14                          co2_per_gdp
# 15              consumption_co2_per_gdp
# 16                  co2_per_unit_energy
# 17                           cement_co2
# 18                             coal_co2
# 19                          flaring_co2
# 20                              gas_co2
# 21                              oil_co2
# ...
