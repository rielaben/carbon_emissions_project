# %% [markdown]
# The first step is to import all the World Bank datasets and combine them together to make a dataset that we can then merge with the carbon emissions dataset. The following 4 screenshots show the steps to consolidate all of the data of interest from the World Bank into a single dataframe:

# %%
import pandas as pd
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_columns', None)

main_df = pd.read_csv("world_bank_data/API_11_DS2_en_csv_v2_2163688.csv", skiprows=4).drop('Unnamed: 65', axis=1)
main_df.head()
# Out:
#   Country Name Country Code  \
# 0        Aruba          ABW
# 1        Aruba          ABW
# 2        Aruba          ABW
# 3        Aruba          ABW
# 4        Aruba          ABW
#
#                                                                                 Indicator Name  \
# 0  Survey mean consumption or income per capita, bottom 40% of population (2011 PPP $ per day)
# 1                                                    Poverty gap at $5.50 a day (2011 PPP) (%)
# 2                          Poverty headcount ratio at $5.50 a day (2011 PPP) (% of population)
# 3                          Poverty headcount ratio at national poverty lines (% of population)
# 4                                                   Multidimensional poverty index (scale 0-1)
#
#    Indicator Code  1960  1961  1962  1963  1964  1965  1966  1967  1968  1969  \
# 0     SI.SPR.PC40   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1  SI.POV.UMIC.GP   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2     SI.POV.UMIC   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3     SI.POV.NAHC   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4  SI.POV.MDIM.XQ   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#    1970  1971  1972  1973  1974  1975  1976  1977  1978  1979  1980  1981  \
# 0   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#    1982  1983  1984  1985  1986  1987  1988  1989  1990  1991  1992  1993  \
# 0   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#    1994  1995  1996  1997  1998  1999  2000  2001  2002  2003  2004  2005  \
# 0   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#    2006  2007  2008  2009  2010  2011  2012  2013  2014  2015  2016  2017  \
# 0   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#    2018  2019  2020
# 0   NaN   NaN   NaN
# 1   NaN   NaN   NaN
# 2   NaN   NaN   NaN
# 3   NaN   NaN   NaN
# 4   NaN   NaN   NaN

# %% [markdown]
# Read in another World Bank dataset, this one gives us information of the Region and Income level

# %%
counties_df = pd.read_csv("world_bank_data/Metadata_Country_API_11_DS2_en_csv_v2_2163688.csv").drop('Unnamed: 5', axis=1)
# If IncomeGroup is Nan, we want to drop the row because we want to look at income for countries
# these other rows are for continents and other groups that are not countries
counties_df = counties_df[pd.notna(counties_df['IncomeGroup'])]
# only columns we care about
counties_df = counties_df[['Country Code', 'Region', 'IncomeGroup']]
counties_df = counties_df.rename(columns={'IncomeGroup':'Income'})
counties_df.head()
# Out:
#   Country Code                     Region               Income
# 0          ABW  Latin America & Caribbean          High income
# 1          AFG                 South Asia           Low income
# 2          AGO         Sub-Saharan Africa  Lower middle income
# 3          ALB      Europe & Central Asia  Upper middle income
# 4          AND      Europe & Central Asia          High income

# %% [markdown]
# Perform an inner merge with the first World Bank dataset to get the country name as well as region and income information

# %%
# merge with other df on "Country Code"
merged_counties = pd.merge(main_df, counties_df, how='inner', on='Country Code')
# filter to only the columns we care about
merged_counties = merged_counties[['Country Name', 'Country Code', 'Region','Income']]
# drop duplicate rows, because each country had 29 duplicates
merged_counties = merged_counties.drop_duplicates().reset_index(drop=True)
merged_counties.head(10)
# Out:
#            Country Name Country Code                      Region  \
# 0                 Aruba          ABW   Latin America & Caribbean
# 1           Afghanistan          AFG                  South Asia
# 2                Angola          AGO          Sub-Saharan Africa
# 3               Albania          ALB       Europe & Central Asia
# 4               Andorra          AND       Europe & Central Asia
# 5  United Arab Emirates          ARE  Middle East & North Africa
# 6             Argentina          ARG   Latin America & Caribbean
# 7               Armenia          ARM       Europe & Central Asia
# 8        American Samoa          ASM         East Asia & Pacific
# 9   Antigua and Barbuda          ATG   Latin America & Caribbean
#
#                 Income
# 0          High income
# 1           Low income
# 2  Lower middle income
# 3  Upper middle income
# 4          High income
# 5          High income
# 6  Upper middle income
# 7  Upper middle income
# 8  Upper middle income
# 9          High income

# %% [markdown]
# Now with the income data in the desired format, we need to add GDP information. We can start by importing the data, and then using the percent_missing_cols function to see the percentage of missing values that for each column in the gdp_df dataframe:

# %%
gdp_df = pd.read_csv("world_bank_data/API_NY.GDP.MKTP.CD_DS2_en_csv_v2_2163564.csv", skiprows=4).drop('Unnamed: 65', axis=1)
gdp_df
# Out:
#      Country Name Country Code     Indicator Name  Indicator Code  \
# 0           Aruba          ABW  GDP (current US$)  NY.GDP.MKTP.CD
# 1     Afghanistan          AFG  GDP (current US$)  NY.GDP.MKTP.CD
# 2          Angola          AGO  GDP (current US$)  NY.GDP.MKTP.CD
# 3         Albania          ALB  GDP (current US$)  NY.GDP.MKTP.CD
# 4         Andorra          AND  GDP (current US$)  NY.GDP.MKTP.CD
# ..            ...          ...                ...             ...
# 259        Kosovo          XKX  GDP (current US$)  NY.GDP.MKTP.CD
# 260   Yemen, Rep.          YEM  GDP (current US$)  NY.GDP.MKTP.CD
# 261  South Africa          ZAF  GDP (current US$)  NY.GDP.MKTP.CD
# 262        Zambia          ZMB  GDP (current US$)  NY.GDP.MKTP.CD
# 263      Zimbabwe          ZWE  GDP (current US$)  NY.GDP.MKTP.CD
#
#              1960          1961          1962          1963          1964  \
# 0             NaN           NaN           NaN           NaN           NaN
# 1    5.377778e+08  5.488889e+08  5.466667e+08  7.511112e+08  8.000000e+08
# 2             NaN           NaN           NaN           NaN           NaN
# 3             NaN           NaN           NaN           NaN           NaN
# 4             NaN           NaN           NaN           NaN           NaN
# ..            ...           ...           ...           ...           ...
# 259           NaN           NaN           NaN           NaN           NaN
# 260           NaN           NaN           NaN           NaN           NaN
# 261  7.575397e+09  7.972997e+09  8.497997e+09  9.423396e+09  1.037400e+10
# 262  7.130000e+08  6.962857e+08  6.931429e+08  7.187143e+08  8.394286e+08
# 263  1.052990e+09  1.096647e+09  1.117602e+09  1.159512e+09  1.217138e+09
#
#              1965          1966          1967          1968          1969  \
# 0             NaN           NaN           NaN           NaN           NaN
# 1    1.006667e+09  1.400000e+09  1.673333e+09  1.373333e+09  1.408889e+09
# 2             NaN           NaN           NaN           NaN           NaN
# 3             NaN           NaN           NaN           NaN           NaN
# 4             NaN           NaN           NaN           NaN           NaN
# ..            ...           ...           ...           ...           ...
# 259           NaN           NaN           NaN           NaN           NaN
# 260           NaN           NaN           NaN           NaN           NaN
# 261  1.133440e+10  1.235500e+10  1.377739e+10  1.489459e+10  1.678039e+10
# 262  1.082857e+09  1.264286e+09  1.368000e+09  1.605857e+09  1.965714e+09
# 263  1.311436e+09  1.281750e+09  1.397002e+09  1.479600e+09  1.747999e+09
#
#              1970          1971          1972          1973          1974  \
# 0             NaN           NaN           NaN           NaN           NaN
# 1    1.748887e+09  1.831109e+09  1.595555e+09  1.733333e+09  2.155555e+09
# 2             NaN           NaN           NaN           NaN           NaN
# 3             NaN           NaN           NaN           NaN           NaN
# 4    7.861921e+07  8.940982e+07  1.134082e+08  1.508201e+08  1.865587e+08
# ..            ...           ...           ...           ...           ...
# 259           NaN           NaN           NaN           NaN           NaN
# 260           NaN           NaN           NaN           NaN           NaN
# 261  1.841839e+10  2.033369e+10  2.135744e+10  2.929567e+10  3.680772e+10
# 262  1.825286e+09  1.687000e+09  1.910714e+09  2.268714e+09  3.121833e+09
# 263  1.884206e+09  2.178716e+09  2.677729e+09  3.309354e+09  3.982161e+09
#
#              1975          1976          1977          1978          1979  \
# 0             NaN           NaN           NaN           NaN           NaN
# 1    2.366667e+09  2.555556e+09  2.953333e+09  3.300000e+09  3.697940e+09
# 2             NaN           NaN           NaN           NaN           NaN
# 3             NaN           NaN           NaN           NaN           NaN
# 4    2.201272e+08  2.272810e+08  2.540202e+08  3.080089e+08  4.115783e+08
# ..            ...           ...           ...           ...           ...
# 259           NaN           NaN           NaN           NaN           NaN
# 260           NaN           NaN           NaN           NaN           NaN
# 261  3.811454e+10  3.660335e+10  4.065135e+10  4.673945e+10  5.764572e+10
# 262  2.618667e+09  2.746714e+09  2.483000e+09  2.813375e+09  3.325500e+09
# 263  4.371301e+09  4.318372e+09  4.364382e+09  4.351600e+09  5.177459e+09
#
#              1980          1981          1982          1983          1984  \
# 0             NaN           NaN           NaN           NaN           NaN
# 1    3.641723e+09  3.478788e+09           NaN           NaN           NaN
# 2    5.930503e+09  5.550483e+09  5.550483e+09  5.784342e+09  6.131475e+09
# 3             NaN           NaN           NaN           NaN  1.857338e+09
# 4    4.464161e+08  3.889587e+08  3.758960e+08  3.278618e+08  3.300707e+08
# ..            ...           ...           ...           ...           ...
# 259           NaN           NaN           NaN           NaN           NaN
# 260           NaN           NaN           NaN           NaN           NaN
# 261  8.298048e+10  8.545442e+10  7.842306e+10  8.741585e+10  7.734409e+10
# 262  3.829500e+09  3.872667e+09  3.994778e+09  3.216308e+09  2.739444e+09
# 263  6.678868e+09  8.011374e+09  8.539701e+09  7.764067e+09  6.352126e+09
#
#              1985          1986          1987          1988          1989  \
# 0             NaN  4.054634e+08  4.876025e+08  5.964236e+08  6.953044e+08
# 1             NaN           NaN           NaN           NaN           NaN
# 2    7.553560e+09  7.072063e+09  8.083872e+09  8.769251e+09  1.020110e+10
# 3    1.897050e+09  2.097326e+09  2.080796e+09  2.051236e+09  2.253090e+09
# 4    3.467380e+08  4.820006e+08  6.113164e+08  7.214259e+08  7.954493e+08
# ..            ...           ...           ...           ...           ...
# 259           NaN           NaN           NaN           NaN           NaN
# 260           NaN           NaN           NaN           NaN           NaN
# 261  5.908264e+10  6.752160e+10  8.857370e+10  9.517664e+10  9.903086e+10
# 262  2.281258e+09  1.661949e+09  2.269895e+09  3.713614e+09  3.998638e+09
# 263  5.637259e+09  6.217524e+09  6.741215e+09  7.814784e+09  8.286323e+09
#
#              1990          1991          1992          1993          1994  \
# 0    7.648871e+08  8.721387e+08  9.584632e+08  1.082980e+09  1.245688e+09
# 1             NaN           NaN           NaN           NaN           NaN
# 2    1.122876e+10  1.060378e+10  8.307811e+09  5.768720e+09  4.438321e+09
# 3    2.028554e+09  1.099559e+09  6.521750e+08  1.185315e+09  1.880952e+09
# 4    1.029048e+09  1.106929e+09  1.210014e+09  1.007026e+09  1.017549e+09
# ..            ...           ...           ...           ...           ...
# 259           NaN           NaN           NaN           NaN           NaN
# 260  5.647119e+09  5.930370e+09  6.463650e+09  5.368271e+09  4.167356e+09
# 261  1.155523e+11  1.239428e+11  1.345446e+11  1.343081e+11  1.397525e+11
# 262  3.285217e+09  3.378882e+09  3.181922e+09  3.273238e+09  3.656648e+09
# 263  8.783817e+09  8.641482e+09  6.751472e+09  6.563813e+09  6.890675e+09
#
#              1995          1996          1997          1998          1999  \
# 0    1.320475e+09  1.379961e+09  1.531944e+09  1.665101e+09  1.722799e+09
# 1             NaN           NaN           NaN           NaN           NaN
# 2    5.538749e+09  7.526447e+09  7.648377e+09  6.506230e+09  6.152923e+09
# 3    2.392765e+09  3.199643e+09  2.258516e+09  2.545967e+09  3.212119e+09
# 4    1.178739e+09  1.223945e+09  1.180597e+09  1.211932e+09  1.239876e+09
# ..            ...           ...           ...           ...           ...
# 259           NaN           NaN           NaN           NaN           NaN
# 260  4.258789e+09  5.785685e+09  6.838557e+09  6.325142e+09  7.641103e+09
# 261  1.554609e+11  1.476063e+11  1.525874e+11  1.377748e+11  1.366323e+11
# 262  3.807067e+09  3.597221e+09  4.303282e+09  3.537683e+09  3.404312e+09
# 263  7.111271e+09  8.553147e+09  8.529572e+09  6.401968e+09  6.858013e+09
#
#              2000          2001          2002          2003          2004  \
# 0    1.873453e+09  1.920112e+09  1.941341e+09  2.021229e+09  2.228492e+09
# 1             NaN           NaN  4.055180e+09  4.515559e+09  5.226779e+09
# 2    9.129595e+09  8.936064e+09  1.528559e+10  1.781271e+10  2.355205e+10
# 3    3.480355e+09  3.922099e+09  4.348070e+09  5.611492e+09  7.184681e+09
# 4    1.429049e+09  1.546926e+09  1.755910e+09  2.361727e+09  2.894922e+09
# ..            ...           ...           ...           ...           ...
# 259  1.849196e+09  2.535334e+09  2.406271e+09  2.790456e+09  3.556757e+09
# 260  9.652436e+09  9.861560e+09  1.069463e+10  1.177797e+10  1.387279e+10
# 261  1.363613e+11  1.215147e+11  1.154824e+11  1.752569e+11  2.285900e+11
# 262  3.600683e+09  4.094481e+09  4.193846e+09  4.901840e+09  6.221078e+09
# 263  6.689958e+09  6.777385e+09  6.342116e+09  5.727592e+09  5.805598e+09
#
#              2005          2006          2007          2008          2009  \
# 0    2.330726e+09  2.424581e+09  2.615084e+09  2.745251e+09  2.498883e+09
# 1    6.209138e+09  6.971286e+09  9.747880e+09  1.010923e+10  1.243909e+10
# 2    3.697092e+10  5.238101e+10  6.526645e+10  8.853861e+10  7.030716e+10
# 3    8.052076e+09  8.896074e+09  1.067732e+10  1.288135e+10  1.204422e+10
# 4    3.159905e+09  3.456442e+09  3.952601e+09  4.085631e+09  3.674410e+09
# ..            ...           ...           ...           ...           ...
# 259  3.663102e+09  3.846820e+09  4.655899e+09  5.687418e+09  5.653793e+09
# 260  1.674634e+10  1.906198e+10  2.165053e+10  2.691085e+10  2.513027e+10
# 261  2.577727e+11  2.716385e+11  2.994155e+11  2.867698e+11  2.959365e+11
# 262  8.331870e+09  1.275686e+10  1.405696e+10  1.791086e+10  1.532834e+10
# 263  5.755215e+09  5.443896e+09  5.291950e+09  4.415703e+09  9.665793e+09
#
#              2010          2011          2012          2013          2014  \
# 0    2.390503e+09  2.549721e+09  2.534637e+09  2.701676e+09  2.765363e+09
# 1    1.585657e+10  1.780429e+10  2.000160e+10  2.056107e+10  2.048489e+10
# 2    8.379950e+10  1.117897e+11  1.280529e+11  1.367099e+11  1.457122e+11
# 3    1.192693e+10  1.289077e+10  1.231983e+10  1.277622e+10  1.322814e+10
# 4    3.449967e+09  3.629204e+09  3.188809e+09  3.193704e+09  3.271808e+09
# ..            ...           ...           ...           ...           ...
# 259  5.835874e+09  6.701698e+09  6.499807e+09  7.074778e+09  7.396705e+09
# 260  3.090675e+10  3.272642e+10  3.540134e+10  4.041524e+10  4.320647e+10
# 261  3.753494e+11  4.164189e+11  3.963327e+11  3.668294e+11  3.509046e+11
# 262  2.026556e+10  2.345952e+10  2.550306e+10  2.804555e+10  2.715073e+10
# 263  1.204166e+10  1.410192e+10  1.711485e+10  1.909102e+10  1.949552e+10
#
#              2015          2016          2017          2018          2019  \
# 0    2.919553e+09  2.965922e+09  3.056425e+09           NaN           NaN
# 1    1.990711e+10  1.801775e+10  1.886995e+10  1.835388e+10  1.929110e+10
# 2    1.161936e+11  1.011239e+11  1.221238e+11  1.013532e+11  8.881570e+10
# 3    1.138685e+10  1.186120e+10  1.301969e+10  1.514702e+10  1.527918e+10
# 4    2.789870e+09  2.896679e+09  3.000181e+09  3.218316e+09  3.154058e+09
# ..            ...           ...           ...           ...           ...
# 259  6.442916e+09  6.719172e+09  7.245707e+09  7.942962e+09  7.926134e+09
# 260  4.245062e+10  3.093598e+10  2.673614e+10  2.348627e+10  2.258108e+10
# 261  3.176205e+11  2.963573e+11  3.495541e+11  3.682889e+11  3.514316e+11
# 262  2.124334e+10  2.095475e+10  2.586817e+10  2.631214e+10  2.330977e+10
# 263  1.996312e+10  2.054868e+10  2.204090e+10  2.431156e+10  2.144076e+10
#
#      2020
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
# ..    ...
# 259   NaN
# 260   NaN
# 261   NaN
# 262   NaN
# 263   NaN
#
# [264 rows x 65 columns]

# %% [markdown]
# This function calculates the percentage of missing values in each column. https://stackoverflow.com/questions/51070985/find-out-the-percentage-of-missing-values-in-each-column-in-the-given-dataset/51071037

# %%
def percent_missing_cols(df):
    percent_missing = df.isnull().sum() * 100 / len(df)
    missing_value_df = pd.DataFrame({'percent_missing': percent_missing})
    return missing_value_df

# %%
percent_missing_cols(gdp_df).tail(5)
# Out:
#       percent_missing
# 2016         4.924242
# 2017         4.924242
# 2018         5.681818
# 2019        12.878788
# 2020       100.000000

# %% [markdown]
# Since 2018 had about 5.7% of values missing, but 2019 had almost 13% values missing, we can isolate the 2018 GDP as the column to perform GDP analysis on. In this analysis, we're only using GDP to measure a country's current economic status, so historical GDP information has no role in this project.

# %%
merged_counties.columns
# Out:
# Index(['Country Name', 'Country Code', 'Region', 'Income'], dtype='object')

# %% [markdown]
# The following code merges the GDP information with the income information of each country and filters on the 2018 GDP information to create a merged dataframe with all the economic information we need for this analysis:

# %%
country_wealth_data = pd.merge(merged_counties, gdp_df, how='inner', on='Country Code').drop("Country Name_y", axis=1).rename(columns={'2018':'2018 GDP', 'Country Name_x':'Country Name'})
country_wealth_data = country_wealth_data[["Country Name", "Country Code", "Region", "Income", "2018 GDP"]]
country_wealth_data.head()
# Out:
#   Country Name Country Code                     Region               Income  \
# 0        Aruba          ABW  Latin America & Caribbean          High income
# 1  Afghanistan          AFG                 South Asia           Low income
# 2       Angola          AGO         Sub-Saharan Africa  Lower middle income
# 3      Albania          ALB      Europe & Central Asia  Upper middle income
# 4      Andorra          AND      Europe & Central Asia          High income
#
#        2018 GDP
# 0           NaN
# 1  1.835388e+10
# 2  1.013532e+11
# 3  1.514702e+10
# 4  3.218316e+09

# %% [markdown]
# The dataset below is Greenhouse Gas emissions data by country by year

# %%
co2_data = pd.read_csv("co2-data/owid-co2-data.csv")

# %%
co2_data.head()
# Out:
#   iso_code      country  year    co2  co2_growth_prct  co2_growth_abs  \
# 0      AFG  Afghanistan  1949  0.015              NaN             NaN
# 1      AFG  Afghanistan  1950  0.084          475.000           0.070
# 2      AFG  Afghanistan  1951  0.092            8.696           0.007
# 3      AFG  Afghanistan  1952  0.092              NaN             NaN
# 4      AFG  Afghanistan  1953  0.106           16.000           0.015
#
#    consumption_co2  trade_co2  trade_co2_share  co2_per_capita  \
# 0              NaN        NaN              NaN           0.002
# 1              NaN        NaN              NaN           0.011
# 2              NaN        NaN              NaN           0.012
# 3              NaN        NaN              NaN           0.012
# 4              NaN        NaN              NaN           0.013
#
#    consumption_co2_per_capita  share_global_co2  cumulative_co2  \
# 0                         NaN             0.000           0.015
# 1                         NaN             0.001           0.099
# 2                         NaN             0.001           0.191
# 3                         NaN             0.001           0.282
# 4                         NaN             0.002           0.388
#
#    share_global_cumulative_co2  co2_per_gdp  consumption_co2_per_gdp  \
# 0                          0.0          NaN                      NaN
# 1                          0.0        0.004                      NaN
# 2                          0.0        0.005                      NaN
# 3                          0.0        0.004                      NaN
# 4                          0.0        0.005                      NaN
#
#    co2_per_unit_energy  cement_co2  coal_co2  flaring_co2  gas_co2  oil_co2  \
# 0                  NaN         NaN     0.015          NaN      NaN      NaN
# 1                  NaN         NaN     0.021          NaN      NaN    0.063
# 2                  NaN         NaN     0.026          NaN      NaN    0.066
# 3                  NaN         NaN     0.032          NaN      NaN    0.060
# 4                  NaN         NaN     0.038          NaN      NaN    0.068
#
#    other_industry_co2  cement_co2_per_capita  coal_co2_per_capita  \
# 0                 NaN                    NaN                0.002
# 1                 NaN                    NaN                0.003
# 2                 NaN                    NaN                0.003
# 3                 NaN                    NaN                0.004
# 4                 NaN                    NaN                0.005
#
#    flaring_co2_per_capita  gas_co2_per_capita  oil_co2_per_capita  \
# 0                     NaN                 NaN                 NaN
# 1                     NaN                 NaN               0.008
# 2                     NaN                 NaN               0.008
# 3                     NaN                 NaN               0.008
# 4                     NaN                 NaN               0.008
#
#    other_co2_per_capita  share_global_coal_co2  share_global_oil_co2  \
# 0                   NaN                  0.000                   NaN
# 1                   NaN                  0.001                 0.004
# 2                   NaN                  0.001                 0.004
# 3                   NaN                  0.001                 0.003
# 4                   NaN                  0.001                 0.003
#
#    share_global_gas_co2  share_global_flaring_co2  share_global_cement_co2  \
# 0                   NaN                       NaN                      NaN
# 1                   NaN                       NaN                      NaN
# 2                   NaN                       NaN                      NaN
# 3                   NaN                       NaN                      NaN
# 4                   NaN                       NaN                      NaN
#
#    cumulative_coal_co2  cumulative_oil_co2  cumulative_gas_co2  \
# 0                0.015                 NaN                 NaN
# 1                0.036               0.063                 NaN
# 2                0.061               0.129                 NaN
# 3                0.093               0.189                 NaN
# 4                0.131               0.257                 NaN
#
#    cumulative_flaring_co2  cumulative_cement_co2  \
# 0                     NaN                    NaN
# 1                     NaN                    NaN
# 2                     NaN                    NaN
# 3                     NaN                    NaN
# 4                     NaN                    NaN
#
#    share_global_cumulative_coal_co2  share_global_cumulative_oil_co2  \
# 0                               0.0                              NaN
# 1                               0.0                            0.000
# 2                               0.0                            0.000
# 3                               0.0                            0.001
# 4                               0.0                            0.001
#
#    share_global_cumulative_gas_co2  share_global_cumulative_flaring_co2  \
# 0                              NaN                                  NaN
# 1                              NaN                                  NaN
# 2                              NaN                                  NaN
# 3                              NaN                                  NaN
# 4                              NaN                                  NaN
#
#    share_global_cumulative_cement_co2  total_ghg  ghg_per_capita  methane  \
# 0                                 NaN        NaN             NaN      NaN
# 1                                 NaN        NaN             NaN      NaN
# 2                                 NaN        NaN             NaN      NaN
# 3                                 NaN        NaN             NaN      NaN
# 4                                 NaN        NaN             NaN      NaN
#
#    methane_per_capita  nitrous_oxide  nitrous_oxide_per_capita  \
# 0                 NaN            NaN                       NaN
# 1                 NaN            NaN                       NaN
# 2                 NaN            NaN                       NaN
# 3                 NaN            NaN                       NaN
# 4                 NaN            NaN                       NaN
#
#    primary_energy_consumption  energy_per_capita  energy_per_gdp  population  \
# 0                         NaN                NaN             NaN   7663783.0
# 1                         NaN                NaN             NaN   7752000.0
# 2                         NaN                NaN             NaN   7840000.0
# 3                         NaN                NaN             NaN   7936000.0
# 4                         NaN                NaN             NaN   8040000.0
#
#             gdp
# 0           NaN
# 1  1.949480e+10
# 2  2.006385e+10
# 3  2.074235e+10
# 4  2.201546e+10

# %% [markdown]
# Now we can finally create a merged dataframe combining the cleaned GDP/income data with the co2 emissions data. The result is a dataframe that contains information for 202 countries from the year data was first available for each country (for some countries this goes back to 1750) until 2019 (the 2020 data was not available at the time of this writing). In total there are 20,098 entries in "merged_df", with the dataframe spanning 19 columns.

# %%
merged_df = pd.merge(country_wealth_data, co2_data, how='inner', left_on='Country Code', right_on='iso_code')
merged_df.head()
# Out:
#   Country Name Country Code                     Region       Income  2018 GDP  \
# 0        Aruba          ABW  Latin America & Caribbean  High income       NaN
# 1        Aruba          ABW  Latin America & Caribbean  High income       NaN
# 2        Aruba          ABW  Latin America & Caribbean  High income       NaN
# 3        Aruba          ABW  Latin America & Caribbean  High income       NaN
# 4        Aruba          ABW  Latin America & Caribbean  High income       NaN
#
#   iso_code country  year    co2  co2_growth_prct  co2_growth_abs  \
# 0      ABW   Aruba  1926  0.033              NaN           0.033
# 1      ABW   Aruba  1927  0.036            7.082           0.002
# 2      ABW   Aruba  1928  0.083          131.402           0.047
# 3      ABW   Aruba  1929  0.103           24.971           0.021
# 4      ABW   Aruba  1930  0.135           30.135           0.031
#
#    consumption_co2  trade_co2  trade_co2_share  co2_per_capita  \
# 0              NaN        NaN              NaN             NaN
# 1              NaN        NaN              NaN             NaN
# 2              NaN        NaN              NaN             NaN
# 3              NaN        NaN              NaN             NaN
# 4              NaN        NaN              NaN             NaN
#
#    consumption_co2_per_capita  share_global_co2  cumulative_co2  \
# 0                         NaN             0.001           0.033
# 1                         NaN             0.001           0.069
# 2                         NaN             0.002           0.152
# 3                         NaN             0.002           0.255
# 4                         NaN             0.003           0.390
#
#    share_global_cumulative_co2  co2_per_gdp  consumption_co2_per_gdp  \
# 0                          0.0          NaN                      NaN
# 1                          0.0          NaN                      NaN
# 2                          0.0          NaN                      NaN
# 3                          0.0          NaN                      NaN
# 4                          0.0          NaN                      NaN
#
#    co2_per_unit_energy  cement_co2  coal_co2  flaring_co2  gas_co2  oil_co2  \
# 0                  NaN         NaN       NaN          NaN      NaN    0.033
# 1                  NaN         NaN       NaN          NaN      NaN    0.036
# 2                  NaN         NaN       NaN          NaN      NaN    0.083
# 3                  NaN         NaN       NaN          NaN      NaN    0.103
# 4                  NaN         NaN       NaN          NaN      NaN    0.135
#
#    other_industry_co2  cement_co2_per_capita  coal_co2_per_capita  \
# 0                 NaN                    NaN                  NaN
# 1                 NaN                    NaN                  NaN
# 2                 NaN                    NaN                  NaN
# 3                 NaN                    NaN                  NaN
# 4                 NaN                    NaN                  NaN
#
#    flaring_co2_per_capita  gas_co2_per_capita  oil_co2_per_capita  \
# 0                     NaN                 NaN                 NaN
# 1                     NaN                 NaN                 NaN
# 2                     NaN                 NaN                 NaN
# 3                     NaN                 NaN                 NaN
# 4                     NaN                 NaN                 NaN
#
#    other_co2_per_capita  share_global_coal_co2  share_global_oil_co2  \
# 0                   NaN                    NaN                 0.007
# 1                   NaN                    NaN                 0.007
# 2                   NaN                    NaN                 0.015
# 3                   NaN                    NaN                 0.017
# 4                   NaN                    NaN                 0.023
#
#    share_global_gas_co2  share_global_flaring_co2  share_global_cement_co2  \
# 0                   NaN                       NaN                      NaN
# 1                   NaN                       NaN                      NaN
# 2                   NaN                       NaN                      NaN
# 3                   NaN                       NaN                      NaN
# 4                   NaN                       NaN                      NaN
#
#    cumulative_coal_co2  cumulative_oil_co2  cumulative_gas_co2  \
# 0                  NaN               0.033                 NaN
# 1                  NaN               0.069                 NaN
# 2                  NaN               0.152                 NaN
# 3                  NaN               0.255                 NaN
# 4                  NaN               0.390                 NaN
#
#    cumulative_flaring_co2  cumulative_cement_co2  \
# 0                     NaN                    NaN
# 1                     NaN                    NaN
# 2                     NaN                    NaN
# 3                     NaN                    NaN
# 4                     NaN                    NaN
#
#    share_global_cumulative_coal_co2  share_global_cumulative_oil_co2  \
# 0                               NaN                            0.000
# 1                               NaN                            0.001
# 2                               NaN                            0.002
# 3                               NaN                            0.003
# 4                               NaN                            0.004
#
#    share_global_cumulative_gas_co2  share_global_cumulative_flaring_co2  \
# 0                              NaN                                  NaN
# 1                              NaN                                  NaN
# 2                              NaN                                  NaN
# 3                              NaN                                  NaN
# 4                              NaN                                  NaN
#
#    share_global_cumulative_cement_co2  total_ghg  ghg_per_capita  methane  \
# 0                                 NaN        NaN             NaN      NaN
# 1                                 NaN        NaN             NaN      NaN
# 2                                 NaN        NaN             NaN      NaN
# 3                                 NaN        NaN             NaN      NaN
# 4                                 NaN        NaN             NaN      NaN
#
#    methane_per_capita  nitrous_oxide  nitrous_oxide_per_capita  \
# 0                 NaN            NaN                       NaN
# 1                 NaN            NaN                       NaN
# 2                 NaN            NaN                       NaN
# 3                 NaN            NaN                       NaN
# 4                 NaN            NaN                       NaN
#
#    primary_energy_consumption  energy_per_capita  energy_per_gdp  population  \
# 0                         NaN                NaN             NaN         NaN
# 1                         NaN                NaN             NaN         NaN
# 2                         NaN                NaN             NaN         NaN
# 3                         NaN                NaN             NaN         NaN
# 4                         NaN                NaN             NaN         NaN
#
#    gdp
# 0  NaN
# 1  NaN
# 2  NaN
# 3  NaN
# 4  NaN

# %%
# how many countries are in the dataset
display(len(merged_df['Country Code'].unique()))
# Out:
# 202

# %%
percent_missing_cols(merged_df)
# Out:
#                                      percent_missing
# Country Name                                0.000000
# Country Code                                0.000000
# Region                                      0.000000
# Income                                      0.000000
# 2018 GDP                                    3.861081
# iso_code                                    0.000000
# country                                     0.000000
# year                                        0.000000
# co2                                         2.438054
# co2_growth_prct                             6.831526
# co2_growth_abs                              6.383720
# consumption_co2                            83.475968
# trade_co2                                  83.635188
# trade_co2_share                            83.635188
# co2_per_capita                              3.373470
# consumption_co2_per_capita                 83.475968
# share_global_co2                            2.438054
# cumulative_co2                              0.303513
# share_global_cumulative_co2                 0.303513
# co2_per_gdp                                36.665340
# consumption_co2_per_gdp                    84.769629
# co2_per_unit_energy                        70.320430
# cement_co2                                 46.507115
# coal_co2                                   30.197035
# flaring_co2                                82.555478
# gas_co2                                    64.190467
# oil_co2                                    15.215444
# other_industry_co2                         93.879988
# cement_co2_per_capita                      46.507115
# coal_co2_per_capita                        30.898597
# flaring_co2_per_capita                     82.555478
# gas_co2_per_capita                         64.190467
# oil_co2_per_capita                         15.598567
# other_co2_per_capita                       93.879988
# share_global_coal_co2                      30.197035
# share_global_oil_co2                       15.215444
# share_global_gas_co2                       64.190467
# share_global_flaring_co2                   82.555478
# share_global_cement_co2                    46.507115
# cumulative_coal_co2                        23.081899
# cumulative_oil_co2                         14.125784
# cumulative_gas_co2                         61.901682
# cumulative_flaring_co2                     79.415862
# cumulative_cement_co2                      44.626331
# share_global_cumulative_coal_co2           23.081899
# share_global_cumulative_oil_co2            14.125784
# share_global_cumulative_gas_co2            61.901682
# share_global_cumulative_flaring_co2        79.415862
# share_global_cumulative_cement_co2         44.626331
# total_ghg                                  74.753707
# ghg_per_capita                             74.753707
# methane                                    74.743756
# methane_per_capita                         74.743756
# nitrous_oxide                              74.743756
# nitrous_oxide_per_capita                   74.743756
# primary_energy_consumption                 70.444820
# energy_per_capita                          70.444820
# energy_per_gdp                             70.444820
# population                                  0.607026
# gdp                                        36.192656

# %%
merged_df = merged_df.reset_index().drop(['index', 'country'], axis=1)

# %%
merged_df.head(2)
# Out:
#   Country Name Country Code                     Region       Income  2018 GDP  \
# 0        Aruba          ABW  Latin America & Caribbean  High income       NaN
# 1        Aruba          ABW  Latin America & Caribbean  High income       NaN
#
#   iso_code  year    co2  co2_growth_prct  co2_growth_abs  consumption_co2  \
# 0      ABW  1926  0.033              NaN           0.033              NaN
# 1      ABW  1927  0.036            7.082           0.002              NaN
#
#    trade_co2  trade_co2_share  co2_per_capita  consumption_co2_per_capita  \
# 0        NaN              NaN             NaN                         NaN
# 1        NaN              NaN             NaN                         NaN
#
#    share_global_co2  cumulative_co2  share_global_cumulative_co2  co2_per_gdp  \
# 0             0.001           0.033                          0.0          NaN
# 1             0.001           0.069                          0.0          NaN
#
#    consumption_co2_per_gdp  co2_per_unit_energy  cement_co2  coal_co2  \
# 0                      NaN                  NaN         NaN       NaN
# 1                      NaN                  NaN         NaN       NaN
#
#    flaring_co2  gas_co2  oil_co2  other_industry_co2  cement_co2_per_capita  \
# 0          NaN      NaN    0.033                 NaN                    NaN
# 1          NaN      NaN    0.036                 NaN                    NaN
#
#    coal_co2_per_capita  flaring_co2_per_capita  gas_co2_per_capita  \
# 0                  NaN                     NaN                 NaN
# 1                  NaN                     NaN                 NaN
#
#    oil_co2_per_capita  other_co2_per_capita  share_global_coal_co2  \
# 0                 NaN                   NaN                    NaN
# 1                 NaN                   NaN                    NaN
#
#    share_global_oil_co2  share_global_gas_co2  share_global_flaring_co2  \
# 0                 0.007                   NaN                       NaN
# 1                 0.007                   NaN                       NaN
#
#    share_global_cement_co2  cumulative_coal_co2  cumulative_oil_co2  \
# 0                      NaN                  NaN               0.033
# 1                      NaN                  NaN               0.069
#
#    cumulative_gas_co2  cumulative_flaring_co2  cumulative_cement_co2  \
# 0                 NaN                     NaN                    NaN
# 1                 NaN                     NaN                    NaN
#
#    share_global_cumulative_coal_co2  share_global_cumulative_oil_co2  \
# 0                               NaN                            0.000
# 1                               NaN                            0.001
#
#    share_global_cumulative_gas_co2  share_global_cumulative_flaring_co2  \
# 0                              NaN                                  NaN
# 1                              NaN                                  NaN
#
#    share_global_cumulative_cement_co2  total_ghg  ghg_per_capita  methane  \
# 0                                 NaN        NaN             NaN      NaN
# 1                                 NaN        NaN             NaN      NaN
#
#    methane_per_capita  nitrous_oxide  nitrous_oxide_per_capita  \
# 0                 NaN            NaN                       NaN
# 1                 NaN            NaN                       NaN
#
#    primary_energy_consumption  energy_per_capita  energy_per_gdp  population  \
# 0                         NaN                NaN             NaN         NaN
# 1                         NaN                NaN             NaN         NaN
#
#    gdp
# 0  NaN
# 1  NaN

# %% [markdown]
# The following code filters the columns so we only keep the columns of interest, then rename some of them to include units

# %%
merged_df = merged_df[['Country Name', 'Country Code', "Region", "Income", '2018 GDP', 'year',
       'co2', 'co2_growth_prct', 'co2_growth_abs',
       'consumption_co2', 'trade_co2', 'trade_co2_share',
       'co2_per_capita', 'consumption_co2_per_capita',
       'share_global_co2', 'cumulative_co2',
       'share_global_cumulative_co2', 'population']]

# %%
merged_df = merged_df.rename(columns=
                               {'Country Name':'country',
                                'Country Code': 'country code',
                                'co2':'co2 (M Tonnes)', 
                                'co2_growth_abs':'co2_growth_abs (M Tonnes)',
                                'consumption_co2':'consumption_co2 (M Tonnes)',
                                'trade_co2': 'trade_co2 (M Tonnes)',
                                'co2_per_capita':'co2_per_capita (Tonnes)',
                                'consumption_co2_per_capita':'consumption_co2_per_capita (Tonnes)',
                                'cumulative_co2':'cumulative_co2 (M Tonnes)'
                                })

# %%
percent_missing_cols(merged_df)
# Out:
#                                      percent_missing
# country                                     0.000000
# country code                                0.000000
# Region                                      0.000000
# Income                                      0.000000
# 2018 GDP                                    3.861081
# year                                        0.000000
# co2 (M Tonnes)                              2.438054
# co2_growth_prct                             6.831526
# co2_growth_abs (M Tonnes)                   6.383720
# consumption_co2 (M Tonnes)                 83.475968
# trade_co2 (M Tonnes)                       83.635188
# trade_co2_share                            83.635188
# co2_per_capita (Tonnes)                     3.373470
# consumption_co2_per_capita (Tonnes)        83.475968
# share_global_co2                            2.438054
# cumulative_co2 (M Tonnes)                   0.303513
# share_global_cumulative_co2                 0.303513
# population                                  0.607026

# %%
merged_df['co2 per 2018 GDP (M Tonnes/USD)'] = merged_df['co2 (M Tonnes)']/merged_df['2018 GDP']

# %%
merged_df.head(10)
# Out:
#   country country code                     Region       Income  2018 GDP  \
# 0   Aruba          ABW  Latin America & Caribbean  High income       NaN
# 1   Aruba          ABW  Latin America & Caribbean  High income       NaN
# 2   Aruba          ABW  Latin America & Caribbean  High income       NaN
# 3   Aruba          ABW  Latin America & Caribbean  High income       NaN
# 4   Aruba          ABW  Latin America & Caribbean  High income       NaN
# 5   Aruba          ABW  Latin America & Caribbean  High income       NaN
# 6   Aruba          ABW  Latin America & Caribbean  High income       NaN
# 7   Aruba          ABW  Latin America & Caribbean  High income       NaN
# 8   Aruba          ABW  Latin America & Caribbean  High income       NaN
# 9   Aruba          ABW  Latin America & Caribbean  High income       NaN
#
#    year  co2 (M Tonnes)  co2_growth_prct  co2_growth_abs (M Tonnes)  \
# 0  1926           0.033              NaN                      0.033
# 1  1927           0.036            7.082                      0.002
# 2  1928           0.083          131.402                      0.047
# 3  1929           0.103           24.971                      0.021
# 4  1930           0.135           30.135                      0.031
# 5  1931           0.112          -16.937                     -0.023
# 6  1932           0.109           -2.169                     -0.002
# 7  1933           0.117            7.009                      0.008
# 8  1934           0.129           10.585                      0.012
# 9  1935           0.145           12.040                      0.016
#
#    consumption_co2 (M Tonnes)  trade_co2 (M Tonnes)  trade_co2_share  \
# 0                         NaN                   NaN              NaN
# 1                         NaN                   NaN              NaN
# 2                         NaN                   NaN              NaN
# 3                         NaN                   NaN              NaN
# 4                         NaN                   NaN              NaN
# 5                         NaN                   NaN              NaN
# 6                         NaN                   NaN              NaN
# 7                         NaN                   NaN              NaN
# 8                         NaN                   NaN              NaN
# 9                         NaN                   NaN              NaN
#
#    co2_per_capita (Tonnes)  consumption_co2_per_capita (Tonnes)  \
# 0                      NaN                                  NaN
# 1                      NaN                                  NaN
# 2                      NaN                                  NaN
# 3                      NaN                                  NaN
# 4                      NaN                                  NaN
# 5                      NaN                                  NaN
# 6                      NaN                                  NaN
# 7                      NaN                                  NaN
# 8                      NaN                                  NaN
# 9                      NaN                                  NaN
#
#    share_global_co2  cumulative_co2 (M Tonnes)  share_global_cumulative_co2  \
# 0             0.001                      0.033                        0.000
# 1             0.001                      0.069                        0.000
# 2             0.002                      0.152                        0.000
# 3             0.002                      0.255                        0.000
# 4             0.003                      0.390                        0.000
# 5             0.003                      0.502                        0.000
# 6             0.003                      0.611                        0.000
# 7             0.004                      0.728                        0.000
# 8             0.004                      0.857                        0.001
# 9             0.004                      1.002                        0.001
#
#    population  co2 per 2018 GDP (M Tonnes/USD)
# 0         NaN                              NaN
# 1         NaN                              NaN
# 2         NaN                              NaN
# 3         NaN                              NaN
# 4         NaN                              NaN
# 5         NaN                              NaN
# 6         NaN                              NaN
# 7         NaN                              NaN
# 8         NaN                              NaN
# 9         NaN                              NaN

# %% [markdown]
# The "Income" column above includes the word "income" after every income category (for example, "High income", "Low income", Upper middle income"), so the following code eliminates the "income" so the column is less repetitive

# %%
merged_df['Income'] = merged_df.apply(lambda x: x['Income'].rsplit(' ', 1)[0], axis=1)
merged_df.head()
# Out:
#   country country code                     Region Income  2018 GDP  year  \
# 0   Aruba          ABW  Latin America & Caribbean   High       NaN  1926
# 1   Aruba          ABW  Latin America & Caribbean   High       NaN  1927
# 2   Aruba          ABW  Latin America & Caribbean   High       NaN  1928
# 3   Aruba          ABW  Latin America & Caribbean   High       NaN  1929
# 4   Aruba          ABW  Latin America & Caribbean   High       NaN  1930
#
#    co2 (M Tonnes)  co2_growth_prct  co2_growth_abs (M Tonnes)  \
# 0           0.033              NaN                      0.033
# 1           0.036            7.082                      0.002
# 2           0.083          131.402                      0.047
# 3           0.103           24.971                      0.021
# 4           0.135           30.135                      0.031
#
#    consumption_co2 (M Tonnes)  trade_co2 (M Tonnes)  trade_co2_share  \
# 0                         NaN                   NaN              NaN
# 1                         NaN                   NaN              NaN
# 2                         NaN                   NaN              NaN
# 3                         NaN                   NaN              NaN
# 4                         NaN                   NaN              NaN
#
#    co2_per_capita (Tonnes)  consumption_co2_per_capita (Tonnes)  \
# 0                      NaN                                  NaN
# 1                      NaN                                  NaN
# 2                      NaN                                  NaN
# 3                      NaN                                  NaN
# 4                      NaN                                  NaN
#
#    share_global_co2  cumulative_co2 (M Tonnes)  share_global_cumulative_co2  \
# 0             0.001                      0.033                          0.0
# 1             0.001                      0.069                          0.0
# 2             0.002                      0.152                          0.0
# 3             0.002                      0.255                          0.0
# 4             0.003                      0.390                          0.0
#
#    population  co2 per 2018 GDP (M Tonnes/USD)
# 0         NaN                              NaN
# 1         NaN                              NaN
# 2         NaN                              NaN
# 3         NaN                              NaN
# 4         NaN                              NaN

# %% [markdown]
# We now need to check the datatypes of the columns and see if the types are what we want

# %%
display(merged_df.dtypes)
# Out:
# country                                 object
# country code                            object
# Region                                  object
# Income                                  object
# 2018 GDP                               float64
# year                                     int64
# co2 (M Tonnes)                         float64
# co2_growth_prct                        float64
# co2_growth_abs (M Tonnes)              float64
# consumption_co2 (M Tonnes)             float64
# trade_co2 (M Tonnes)                   float64
# trade_co2_share                        float64
# co2_per_capita (Tonnes)                float64
# consumption_co2_per_capita (Tonnes)    float64
# share_global_co2                       float64
# cumulative_co2 (M Tonnes)              float64
# share_global_cumulative_co2            float64
# population                             float64
# co2 per 2018 GDP (M Tonnes/USD)        float64
# dtype: object

# %% [markdown]
# While the majority of this is fine, we can change the data type for 2 columns. One is the "Income" column. This is because "Income" is an ordinal variable (a ranked categorical variable), and therefore it should be converted to type "category". This can be done with the following code.

# %%
display(merged_df['Income'].unique())
# Out:
# array(['High', 'Low', 'Lower middle', 'Upper middle'], dtype=object)

# %%
# Create assign the category ranking
my_categories = pd.CategoricalDtype(categories = ['Low', 'Lower middle', 'Upper middle', 'High'],
                                    ordered=True)

# Convert income column from type object to type category
# Now we have ordering to the Income variable, where 'High' is at the top and 'Low' is at the bottom
merged_df['Income'] = merged_df['Income'].astype(my_categories)
display(merged_df.head())
display(merged_df.dtypes)
# Out:
#   country country code                     Region Income  2018 GDP  year  \
# 0   Aruba          ABW  Latin America & Caribbean   High       NaN  1926
# 1   Aruba          ABW  Latin America & Caribbean   High       NaN  1927
# 2   Aruba          ABW  Latin America & Caribbean   High       NaN  1928
# 3   Aruba          ABW  Latin America & Caribbean   High       NaN  1929
# 4   Aruba          ABW  Latin America & Caribbean   High       NaN  1930
#
#    co2 (M Tonnes)  co2_growth_prct  co2_growth_abs (M Tonnes)  \
# 0           0.033              NaN                      0.033
# 1           0.036            7.082                      0.002
# 2           0.083          131.402                      0.047
# 3           0.103           24.971                      0.021
# 4           0.135           30.135                      0.031
#
#    consumption_co2 (M Tonnes)  trade_co2 (M Tonnes)  trade_co2_share  \
# 0                         NaN                   NaN              NaN
# 1                         NaN                   NaN              NaN
# 2                         NaN                   NaN              NaN
# 3                         NaN                   NaN              NaN
# 4                         NaN                   NaN              NaN
#
#    co2_per_capita (Tonnes)  consumption_co2_per_capita (Tonnes)  \
# 0                      NaN                                  NaN
# 1                      NaN                                  NaN
# 2                      NaN                                  NaN
# 3                      NaN                                  NaN
# 4                      NaN                                  NaN
#
#    share_global_co2  cumulative_co2 (M Tonnes)  share_global_cumulative_co2  \
# 0             0.001                      0.033                          0.0
# 1             0.001                      0.069                          0.0
# 2             0.002                      0.152                          0.0
# 3             0.002                      0.255                          0.0
# 4             0.003                      0.390                          0.0
#
#    population  co2 per 2018 GDP (M Tonnes/USD)
# 0         NaN                              NaN
# 1         NaN                              NaN
# 2         NaN                              NaN
# 3         NaN                              NaN
# 4         NaN                              NaN
# country                                  object
# country code                             object
# Region                                   object
# Income                                 category
# 2018 GDP                                float64
# year                                      int64
# co2 (M Tonnes)                          float64
# co2_growth_prct                         float64
# co2_growth_abs (M Tonnes)               float64
# consumption_co2 (M Tonnes)              float64
# trade_co2 (M Tonnes)                    float64
# trade_co2_share                         float64
# co2_per_capita (Tonnes)                 float64
# consumption_co2_per_capita (Tonnes)     float64
# share_global_co2                        float64
# cumulative_co2 (M Tonnes)               float64
# share_global_cumulative_co2             float64
# population                              float64
# co2 per 2018 GDP (M Tonnes/USD)         float64
# dtype: object

# %% [markdown]
# Now that this is a category, we can make queries such as the following, which returns only countries with incomes of "Upper middle" or higher:

# %%
display(merged_df[merged_df['Income'] >= 'Upper middle'][['country', 'Income']].drop_duplicates().reset_index().drop('index', axis=1))
# Out:
#                             country        Income
# 0                             Aruba          High
# 1                           Albania  Upper middle
# 2                           Andorra          High
# 3              United Arab Emirates          High
# 4                         Argentina  Upper middle
# ..                              ...           ...
# 119  St. Vincent and the Grenadines  Upper middle
# 120                   Venezuela, RB  Upper middle
# 121          British Virgin Islands          High
# 122                           Samoa  Upper middle
# 123                    South Africa  Upper middle
#
# [124 rows x 2 columns]

# %% [markdown]
# The other column we can change the data type of is the "year" column. Although this is not completely necessary, this conversion allows to practice working with time series data. With the following code, we can convert the "year" column from type int to type datetime64.

# %%
merged_df['year'] = pd.to_datetime(merged_df['year'], format='%Y')
merged_df.dtypes
# Out:
# country                                        object
# country code                                   object
# Region                                         object
# Income                                       category
# 2018 GDP                                      float64
# year                                   datetime64[ns]
# co2 (M Tonnes)                                float64
# co2_growth_prct                               float64
# co2_growth_abs (M Tonnes)                     float64
# consumption_co2 (M Tonnes)                    float64
# trade_co2 (M Tonnes)                          float64
# trade_co2_share                               float64
# co2_per_capita (Tonnes)                       float64
# consumption_co2_per_capita (Tonnes)           float64
# share_global_co2                              float64
# cumulative_co2 (M Tonnes)                     float64
# share_global_cumulative_co2                   float64
# population                                    float64
# co2 per 2018 GDP (M Tonnes/USD)               float64
# dtype: object

# %%
merged_df.to_csv (r'cleaned_data.csv')
